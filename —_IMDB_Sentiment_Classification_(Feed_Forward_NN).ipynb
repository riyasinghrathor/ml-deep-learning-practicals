# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load IMDB dataset (pre-tokenized)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Vectorization function
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Vectorize input data
x_train = vectorize_sequences(x_train)
x_test = vectorize_sequences(x_test)

# Convert labels to float32
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')

# Build model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(10000,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train model
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=512,
    validation_split=0.2
)

# Evaluate model
results = model.evaluate(x_test, y_test)
print('Test Accuracy:', results[1])

loss, accuracy = model.evaluate(x_test, y_test)
print('test accuracy', accuracy)

predictions = model.predict(x_test)
for i in range(5):
    print('predicted:', int(predictions[i]>0.5),
          'actual:', int(y_test[i]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.7782 - loss: 0.5430 - val_accuracy: 0.8712 - val_loss: 0.3949
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9002 - loss: 0.3041 - val_accuracy: 0.8848 - val_loss: 0.2997
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9263 - loss: 0.2145 - val_accuracy: 0.8880 - val_loss: 0.2815
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9414 - loss: 0.1718 - val_accuracy: 0.8914 - val_loss: 0.2794
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9548 - loss: 0.1390 - val_accuracy: 0.8890 - val_loss: 0.2877
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9638 - loss: 0.1160 - val_accuracy: 0.8876 - val_loss: 0.3108
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9722 - loss: 0.0959 - val_accuracy: 0.8854 - val_loss: 0.3273
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9801 - loss: 0.0775 - val_accuracy: 0.8818 - val_loss: 0.3507
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9855 - loss: 0.0619 - val_accuracy: 0.8784 - val_loss: 0.3823
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9908 - loss: 0.0479 - val_accuracy: 0.8752 - val_loss: 0.4096
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8665 - loss: 0.4342
# Test Accuracy: 0.8665199875831604
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8665 - loss: 0.4342
# test accuracy 0.8665199875831604
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# predicted: 0 actual: 0
# predicted: 1 actual: 1
# predicted: 0 actual: 1
# predicted: 1 actual: 0
# predicted: 1 actual: 1
# /tmp/ipykernel_3049/1381328668.py:54: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('predicted:', int(predictions[i]>0.5),
